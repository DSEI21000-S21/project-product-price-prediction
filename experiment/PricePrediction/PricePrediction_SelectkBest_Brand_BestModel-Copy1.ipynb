# %%
import sys
sys.path.append(r'C:\\Users\lzowe\OneDrive - The City College of New York\CCNY_Course\Applied_Machine_Learning_and_Data_Mining\codes\project-product-price-prediction')

# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: scipy>=0.14 in c:\users\lzowe\anaconda3\lib\site-packages (from keras) (1.5.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\lzowe\anaconda3\lib\site-packages (from keras) (1.18.5)
# Requirement already satisfied: h5py in c:\users\lzowe\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: pyyaml in c:\users\lzowe\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: six in c:\users\lzowe\appdata\roaming\python\python38\site-packages (from h5py->keras) (1.15.0)
# Installing collected packages: keras
# Successfully installed keras-2.4.3

# %%
import warnings
warnings.filterwarnings("ignore")

import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
matplotlib.rcParams['figure.figsize'] = (15, 10)
plt.rcParams['figure.constrained_layout.use'] = True


# dimension reduction



# model
import lightgbm as lgbm
from sklearn.linear_model import Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor


from final.random_sampling.even_sample_brand import stratified_sampling_by_brand
from final.feature_extraction.text_vectorization import encode_categories,encode_string_column


from final.model_evaluation.error_function import mape
from final.model_evaluation.visualizations import plot_prediction_price
from final.model_evaluation.regression_cvs import find_train_best_model
from final.model_evaluation.keras_model import neural_network
from final.model_evaluation.regression_evaluation import reg_evaluation, get_ori_price
from final.model_evaluation.visualizations import plot_loss

# %% [markdown]
# # Get sample df

# %%
df = pd.read_csv("../../data/sampling_50000_brand_name_data.csv")

# %%
df.shape
# Out:
# (50000, 48)

# %%
df.head(5)
# Out:
#         brand_name  Unnamed: 1  train_id  item_condition_id     brand_name.1  \
# 0    mitchell ness      219343    219537                  1    mitchell ness
# 1            sanuk     1142856   1143963                  1            sanuk
# 2         mary kay      805789    806555                  2         mary kay
# 3  levi strauss co      146324    146465                  2  levi strauss co
# 4              van      534869    535365                  1              van
#
#    price  shipping      c1                 c2           c3  ...  \
# 0   40.0         0     men  men s accessories          hat  ...
# 1   38.0         0   woman               shoe       sandal  ...
# 2    8.0         0  beauty             makeup  makeup sets  ...
# 3   32.0         0   woman               jean  slim skinny  ...
# 4   14.0         1     men   athletic apparel         sock  ...
#
#   brand_nameLength brand_nameLowerCount  brand_nameLowerRatio  \
# 0         0.324324             0.352941              0.923077
# 1         0.108108             0.147059              1.000000
# 2         0.189189             0.205882              0.875000
# 3         0.378378             0.382353              0.866667
# 4         0.054054             0.088235              1.000000
#
#    brand_nameAvgWordLen  nameStopWordCount  namePunctuationCount  \
# 0              0.392857                0.0              0.034483
# 1              0.285714                0.0              0.000000
# 2              0.214286                0.0              0.000000
# 3              0.285714                0.0              0.034483
# 4              0.142857                0.0              0.103448
#
#    nameSpecialCount  item_descriptionStopWordCount  \
# 0          0.052632                       0.008197
# 1          0.000000                       0.008197
# 2          0.000000                       0.008197
# 3          0.000000                       0.073770
# 4          0.000000                       0.008197
#
#    item_descriptionPunctuationCount  item_descriptionSpecialCount
# 0                          0.000000                      0.000000
# 1                          0.001916                      0.001183
# 2                          0.003831                      0.000000
# 3                          0.005747                      0.001183
# 4                          0.001916                      0.001183
#
# [5 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 48 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   brand_name                        50000 non-null  object
#  1   Unnamed: 1                        50000 non-null  int64
#  2   train_id                          50000 non-null  int64
#  3   item_condition_id                 50000 non-null  int64
#  4   brand_name.1                      50000 non-null  object
#  5   price                             50000 non-null  float64
#  6   shipping                          50000 non-null  int64
#  7   c1                                50000 non-null  object
#  8   c2                                50000 non-null  object
#  9   c3                                50000 non-null  object
#  10  clean_name                        50000 non-null  object
#  11  clean_description                 50000 non-null  object
#  12  clean_nameWordCount               50000 non-null  float64
#  13  clean_nameLength                  50000 non-null  float64
#  14  clean_nameLowerCount              50000 non-null  float64
#  15  clean_nameLowerRatio              50000 non-null  float64
#  16  clean_nameAvgWordLen              50000 non-null  float64
#  17  clean_descriptionWordCount        50000 non-null  float64
#  18  clean_descriptionLength           50000 non-null  float64
#  19  clean_descriptionLowerCount       50000 non-null  float64
#  20  clean_descriptionLowerRatio       50000 non-null  float64
#  21  clean_descriptionAvgWordLen       50000 non-null  float64
#  22  c1WordCount                       50000 non-null  float64
#  23  c1Length                          50000 non-null  float64
#  24  c1LowerCount                      50000 non-null  float64
#  25  c1LowerRatio                      50000 non-null  float64
#  26  c1AvgWordLen                      50000 non-null  float64
#  27  c2WordCount                       50000 non-null  float64
#  28  c2Length                          50000 non-null  float64
#  29  c2LowerCount                      50000 non-null  float64
#  30  c2LowerRatio                      50000 non-null  float64
#  31  c2AvgWordLen                      50000 non-null  float64
#  32  c3WordCount                       50000 non-null  float64
#  33  c3Length                          50000 non-null  float64
#  34  c3LowerCount                      50000 non-null  float64
#  35  c3LowerRatio                      50000 non-null  float64
#  36  c3AvgWordLen                      50000 non-null  float64
#  37  brand_nameWordCount               50000 non-null  float64
#  38  brand_nameLength                  50000 non-null  float64
#  39  brand_nameLowerCount              50000 non-null  float64
#  40  brand_nameLowerRatio              50000 non-null  float64
#  41  brand_nameAvgWordLen              50000 non-null  float64
#  42  nameStopWordCount                 50000 non-null  float64
#  43  namePunctuationCount              50000 non-null  float64
#  44  nameSpecialCount                  50000 non-null  float64
#  45  item_descriptionStopWordCount     50000 non-null  float64
#  46  item_descriptionPunctuationCount  50000 non-null  float64
#  47  item_descriptionSpecialCount      50000 non-null  float64
# dtypes: float64(37), int64(4), object(7)
# memory usage: 18.3+ MB

# %% [markdown]
# # Train Test Split

# %%
Y = np.log1p(df['price'])
df.drop(['price'], axis=1, inplace=True)
df.head(2)
# Out:
#       brand_name  Unnamed: 1  train_id  item_condition_id   brand_name.1  \
# 0  mitchell ness      219343    219537                  1  mitchell ness
# 1          sanuk     1142856   1143963                  1          sanuk
#
#    shipping     c1                 c2      c3  \
# 0         0    men  men s accessories     hat
# 1         0  woman               shoe  sandal
#
#                               clean_name  ... brand_nameLength  \
# 0  dallas mavs houston rockets snapbacks  ...         0.324324
# 1                   sanuk sandals size 7  ...         0.108108
#
#    brand_nameLowerCount  brand_nameLowerRatio  brand_nameAvgWordLen  \
# 0              0.352941              0.923077              0.392857
# 1              0.147059              1.000000              0.285714
#
#    nameStopWordCount  namePunctuationCount  nameSpecialCount  \
# 0                0.0              0.034483          0.052632
# 1                0.0              0.000000          0.000000
#
#    item_descriptionStopWordCount  item_descriptionPunctuationCount  \
# 0                       0.008197                          0.000000
# 1                       0.008197                          0.001916
#
#    item_descriptionSpecialCount
# 0                      0.000000
# 1                      0.001183
#
# [2 rows x 47 columns]

# %%
train_df, test_df , y_train, y_test = train_test_split(df, Y, test_size=0.2, random_state=12342)
print('Train size: %s, Test size: %s'%(train_df.shape, test_df.shape))
# Out:
# Train size: (40000, 47), Test size: (10000, 47)

# %% [markdown]
# # Vectorization

# %%
train_cat_features, test_cat_features, train_cat_features_name = encode_categories(train_df, test_df,
                                                                columns = ['c1','c2','c3','brand_name'], 
                                                                min_df = 10, print_progress=True)
# Out:
# Size of vectorization features of c1 is 12
# Size of vectorization features of c2 is 106
# Size of vectorization features of c3 is 386
# Size of vectorization features of brand_name is 726
# Shape of train vectorization features of ['c1', 'c2', 'c3', 'brand_name'] is (40000, 1230)
# Shape of test vectorization features of ['c1', 'c2', 'c3', 'brand_name'] is (10000, 1230)

# %%
train_str_features, test_str_features, train_str_features_name = encode_string_column(train_df, test_df,
                                                                   columns=['clean_name', 'clean_description'],
                                                                   min_df=10, max_features={'clean_name':100, 'clean_description':10000}, 
                                                                   print_progress=True)
# Out:
# Size of vectorization features of clean_name is 100
# Size of vectorization features of clean_description is 10000
# Shape of train vectorization features of ['clean_name', 'clean_description'] is (40000, 10100)
# Shape of test vectorization features of ['clean_name', 'clean_description'] is (10000, 10100)

# %% [markdown]
# # Combine all features

# %%
other_columns = list(train_df.select_dtypes([np.number]).columns)
other_columns.remove('train_id')

# %%
train_other_features = train_df[other_columns].values
test_other_features = test_df[other_columns].values
print('Train other features size: %s, Test other features size: %s'%(train_other_features.shape, 
                                                                     test_other_features.shape))
# Out:
# Train other features size: (40000, 39), Test other features size: (10000, 39)

# %%
all_train = np.hstack((train_cat_features, train_str_features, train_other_features))
all_test = np.hstack((test_cat_features, test_str_features, test_other_features))
print('Train features size: %s, Test features size: %s'%(all_train.shape, 
                                                         all_test.shape))
# Out:
# Train features size: (40000, 11369), Test features size: (10000, 11369)

# %%
del train_cat_features, train_str_features, train_other_features
del test_cat_features, test_str_features, test_other_features

# %% [markdown]
# # Dimension Reduction

# %% [markdown]
# # PCA

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train_std = sc.fit_transform(all_train)
X_test_std = sc.transform(all_test)

# %%
X_train_std.shape
# Out:
# (40000, 11369)

# %%
del all_train, all_test

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components
#        0.00030424, 0.00030381, 0.00030362, 0.00030269, 0.00030248,
#        0.00030219, 0.00030216, 0.00030141, 0.00030112, 0.00030098,
#        0.00030027, 0.00029934, 0.00029911, 0.00029883, 0.00029851,
#        0.00029821, 0.00029792, 0.00029779, 0.00029705, 0.00029692,
#        0.00029624, 0.00029605, 0.00029589, 0.00029569, 0.00029547,
#        0.00029498, 0.00029459, 0.0002942 , 0.00029388, 0.00029359,
#        0.00029326, 0.00029297, 0.00029246, 0.00029203, 0.00029152,
#        0.00029082, 0.00029036, 0.00029003, 0.00028945, 0.00028934,
#        0.000289  , 0.0002885 , 0.00028813, 0.000288  , 0.00028768,
#        0.00028721, 0.00028675, 0.0002861 , 0.00028574, 0.00028555,
#        0.00028535, 0.00028528, 0.00028478, 0.00028431, 0.00028384,
#        0.00028336, 0.00028304, 0.00028255, 0.00028229, 0.000282  ,
#        0.00028127, 0.00028098, 0.00028041, 0.00028022, 0.00027975,
#        0.00027941, 0.00027907, 0.00027862, 0.00027814, 0.00027784,
#        0.00027743, 0.00027732, 0.00027685, 0.00027661, 0.00027589,
#        0.0002754 , 0.00027503, 0.00027485, 0.0002742 , 0.00027412,
#        0.00027318, 0.00027292, 0.00027257, 0.00027146, 0.00027106,
#        0.00027072, 0.00027064, 0.00027003, 0.00026953, 0.00026914,
#        0.00026876, 0.00026856, 0.00026825, 0.00026789, 0.00026703,
#        0.00026698, 0.00026636, 0.00026596, 0.00026531, 0.00026504,
#        0.00026449, 0.00026338, 0.00026264, 0.00026214, 0.00026159])

# %%
x_skb_select_train.shape
# Out:
# (40000, 500)

# %%
x_skb_select_test.shape
# Out:
# (10000, 500)

# %% [markdown]
# # Best Hyparameter Test

# %% [markdown]
# ### Ridge Model - Select K Best

# %%
ridge_model = Ridge(max_iter=100, tol=0.05, alpha=6.0)
ridge_model.fit(x_skb_select_train, y_train)
ridge_train_pred = ridge_model.predict(x_skb_select_train)
ridge_test_pred = ridge_model.predict(x_skb_select_test)

# %%
ridge_train_pred.max()
# Out:
# 6.25442003845227

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
ori_train_price, ori_test_price, pred_train_price, pred_test_price = get_ori_price(y_train, ridge_train_pred, 
                                                                                   y_test,ridge_test_pred)

# %%
pred_train_price.max()
# Out:
# 519.3075288766452

# %%
result_df = reg_evaluation(ori_train_price, ori_test_price, pred_train_price, pred_test_price,  # origin price
               y_train.values, ridge_train_pred, y_test.values, ridge_test_pred,
               price_split=30,print_result = False)
# Out:
# Max Percentage Difference: 1434.54 ---- Original Price 9.00, Predict Price 138.11
# Min Percentage Difference: 0.00 ---- Original Price 18.00, Predict Price 18.00
# Max Percentage Difference: 1434.54 ---- Original Price 9.00, Predict Price 138.11
# Min Percentage Difference: 0.00 ---- Original Price 18.00, Predict Price 18.00
# Max Percentage Difference: 458.03 ---- Original Price 41.00, Predict Price 228.79
# Min Percentage Difference: 0.02 ---- Original Price 40.00, Predict Price 40.01
# Max Percentage Difference: 1341.28 ---- Original Price 14.00, Predict Price 201.78
# Min Percentage Difference: 0.00 ---- Original Price 86.00, Predict Price 86.00
# Max Percentage Difference: 1341.28 ---- Original Price 14.00, Predict Price 201.78
# Min Percentage Difference: 0.00 ---- Original Price 26.00, Predict Price 26.00
# Max Percentage Difference: 319.02 ---- Original Price 85.00, Predict Price 356.17
# Min Percentage Difference: 0.00 ---- Original Price 86.00, Predict Price 86.00

# %%
result_df
# Out:
#                         Max Percentage Diff  Min Percentage Diff     RMSLE  \
# All Train                       1434.543501             0.000689  0.601907
# Train with Price <= 30          1434.543501             0.000689  0.492786
# Train with Price > 30            458.033502             0.024512  0.852583
# All Test                        1341.279077             0.002388  0.608372
# Test with Price <= 30           1341.279077             0.002930  0.493711
# Test with Price > 30             319.022992             0.002388  0.866273
#
#                              R^2       MAPE        MAE
# All Train               0.380395  54.914994  15.032191
# Train with Price <= 30 -0.211251  57.254498   6.570765
# Train with Price > 30  -1.285654  47.774186  40.858785
# All Test                0.370792  55.185412  15.306950
# Test with Price <= 30  -0.212760  57.806913   6.582097
# Test with Price > 30   -1.371010  47.295683  41.565472

# %% [markdown]
# ## RandomForestRegressor

# %% [markdown]
# ### Train with select k best features

# %%
rf_model = RandomForestRegressor(n_estimators=200, max_features=50)
rf_model.fit(x_skb_select_train, y_train)
rf_train_pred = rf_model.predict(x_skb_select_train)
rf_test_pred = rf_model.predict(x_skb_select_test)

# %%
ori_train_price, ori_test_price, pred_train_price, pred_test_price = get_ori_price(y_train, rf_train_pred, 
                                                                                   y_test,rf_test_pred)

result_df = reg_evaluation(ori_train_price, ori_test_price, pred_train_price, pred_test_price,  # origin price
               y_train.values, rf_train_pred, y_test.values, rf_test_pred,
               price_split=30,print_result = False)
# Out:
# Max Percentage Difference: 173.71 ---- Original Price 12.00, Predict Price 32.85
# Min Percentage Difference: 0.00 ---- Original Price 13.00, Predict Price 13.00
# Max Percentage Difference: 173.71 ---- Original Price 12.00, Predict Price 32.85
# Min Percentage Difference: 0.00 ---- Original Price 13.00, Predict Price 13.00
# Max Percentage Difference: 88.59 ---- Original Price 37.00, Predict Price 69.78
# Min Percentage Difference: 0.01 ---- Original Price 32.00, Predict Price 32.00
# Max Percentage Difference: 851.67 ---- Original Price 3.00, Predict Price 28.55
# Min Percentage Difference: 0.01 ---- Original Price 24.00, Predict Price 24.00
# Max Percentage Difference: 851.67 ---- Original Price 3.00, Predict Price 28.55
# Min Percentage Difference: 0.01 ---- Original Price 24.00, Predict Price 24.00
# Max Percentage Difference: 270.03 ---- Original Price 40.00, Predict Price 148.01
# Min Percentage Difference: 0.11 ---- Original Price 34.00, Predict Price 33.96

# %%
result_df
# Out:
#                         Max Percentage Diff  Min Percentage Diff     RMSLE  \
# All Train                        173.712216         5.738999e-13  0.227503
# Train with Price <= 30           173.712216         5.738999e-13  0.182725
# Train with Price > 30             88.585826         8.741716e-03  0.328368
# All Test                         851.674088         6.418524e-03  0.613652
# Test with Price <= 30            851.674088         6.418524e-03  0.482262
# Test with Price > 30             270.029749         1.073530e-01  0.899960
#
#                              R^2       MAPE        MAE
# All Train               0.911482  18.917126   6.981350
# Train with Price <= 30  0.833462  17.592969   2.040955
# Train with Price > 30   0.660954  22.958817  22.060794
# All Test                0.359823  55.256842  15.393059
# Test with Price <= 30  -0.157166  57.453080   6.143146
# Test with Price > 30   -1.559001  48.646994  43.231811

# %% [markdown]
# # Light GBM Regressor

# %% [markdown]
# ### Train with select k best features

# %%
lgbm_model = lgbm.LGBMRegressor(n_estimators=200, max_depth=8,learning_rate=0.1)
lgbm_model.fit(x_skb_select_train, y_train)
lgbm_train_pred = lgbm_model.predict(x_skb_select_train)
lgbm_test_pred = lgbm_model.predict(x_skb_select_test)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).

# %%
ori_train_price, ori_test_price, pred_train_price, pred_test_price = get_ori_price(y_train, lgbm_train_pred,
                                                                                   y_test, lgbm_test_pred)

result_df = reg_evaluation(ori_train_price, ori_test_price, pred_train_price, pred_test_price,  # origin price
               y_train.values, lgbm_train_pred, y_test.values, lgbm_test_pred,
               price_split=30,print_result = True)
# Out:
# --------------------------------------------------
# For All Price
# Train Result ----------
# Max Percentage Difference: 635.02 ---- Original Price 9.00, Predict Price 66.15
# Min Percentage Difference: 0.00 ---- Original Price 19.00, Predict Price 19.00
# RMSLE is  0.46707661960022695
# R^2  is  0.6268938406685324
# Mean Absolute Percentage Error is  41.25612524131107
# Mean Absolute Error is  11.799633287034455
#
# Test Result ----------
# Max Percentage Difference: 1005.18 ---- Original Price 9.00, Predict Price 99.47
# Min Percentage Difference: 0.00 ---- Original Price 21.00, Predict Price 21.00
# RMSLE is  0.5916389468639592
# R^2 is  0.4049272934669348
# Mean Absolute Percentage Error is  53.20631142842769
# Mean Absolute Error is  14.847594286053514
# --------------------------------------------------
# For price under $30
# Train Result ----------
# Max Percentage Difference: 635.02 ---- Original Price 9.00, Predict Price 66.15
# Min Percentage Difference: 0.00 ---- Original Price 19.00, Predict Price 19.00
# RMSLE is  0.39140720078742297
# R^2  is  0.23585657751494704
# Mean Absolute Percentage Error is  42.1368217942179
# Mean Absolute Error is  4.939378735236535
#
# Test Result ----------
# Max Percentage Difference: 1005.18 ---- Original Price 9.00, Predict Price 99.47
# Min Percentage Difference: 0.00 ---- Original Price 21.00, Predict Price 21.00
# RMSLE is  0.4798997677116183
# R^2 is  -0.1458574918213773
# Mean Absolute Percentage Error is  55.49474299685647
# Mean Absolute Error is  6.383776128330692
# --------------------------------------------------
# For price above $30
# Train Result ----------
# Max Percentage Difference: 259.03 ---- Original Price 37.00, Predict Price 132.84
# Min Percentage Difference: 0.00 ---- Original Price 36.00, Predict Price 36.00
# RMSLE is  0.6453210640302739
# R^2  is  -0.30944841530533695
# Mean Absolute Percentage Error is  38.56799775245179
# Mean Absolute Error is  32.73901221430825
#
# Test Result ----------
# Max Percentage Difference: 281.69 ---- Original Price 40.00, Predict Price 152.68
# Min Percentage Difference: 0.11 ---- Original Price 35.00, Predict Price 34.96
# RMSLE is  0.8428448334891058
# R^2 is  -1.2444981274043614
# Mean Absolute Percentage Error is  46.31899492777556
# Mean Absolute Error is  40.3204968890477
# Max Percentage Difference: 635.02 ---- Original Price 9.00, Predict Price 66.15
# Min Percentage Difference: 0.00 ---- Original Price 19.00, Predict Price 19.00
# Max Percentage Difference: 635.02 ---- Original Price 9.00, Predict Price 66.15
# Min Percentage Difference: 0.00 ---- Original Price 19.00, Predict Price 19.00
# Max Percentage Difference: 259.03 ---- Original Price 37.00, Predict Price 132.84
# Min Percentage Difference: 0.00 ---- Original Price 36.00, Predict Price 36.00
# Max Percentage Difference: 1005.18 ---- Original Price 9.00, Predict Price 99.47
# Min Percentage Difference: 0.00 ---- Original Price 21.00, Predict Price 21.00
# Max Percentage Difference: 1005.18 ---- Original Price 9.00, Predict Price 99.47
# Min Percentage Difference: 0.00 ---- Original Price 21.00, Predict Price 21.00
# Max Percentage Difference: 281.69 ---- Original Price 40.00, Predict Price 152.68
# Min Percentage Difference: 0.11 ---- Original Price 35.00, Predict Price 34.96

# %%
result_df
# Out:
#                         Max Percentage Diff  Min Percentage Diff     RMSLE  \
# All Train                        635.023125             0.000917  0.467077
# Train with Price <= 30           635.023125             0.000917  0.391407
# Train with Price > 30            259.028909             0.003795  0.645321
# All Test                        1005.184725             0.000529  0.591639
# Test with Price <= 30           1005.184725             0.000529  0.479900
# Test with Price > 30             281.691886             0.113582  0.842845
#
#                              R^2       MAPE        MAE
# All Train               0.626894  41.256125  11.799633
# Train with Price <= 30  0.235857  42.136822   4.939379
# Train with Price > 30  -0.309448  38.567998  32.739012
# All Test                0.404927  53.206311  14.847594
# Test with Price <= 30  -0.145857  55.494743   6.383776
# Test with Price > 30   -1.244498  46.318995  40.320497

# %% [markdown]
# # Neural Network

# %% [markdown]
# ### Train with select k best features

# %%
model = neural_network(model_prefix="select_k_best_brand_sample", nodes=[64, 16, 16], dropouts = [0.1,0.1,0.1])
model.fit(x_skb_select_train, y_train.values, x_skb_select_test, y_test.values,
          n_epoch=20,epoch=1, bs=128)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 3.6916 - val_loss: 0.9240
# Epoch 2/2
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4030 - val_loss: 0.6761
# Epoch 3/3
# 313/313 [==============================] - 1s 2ms/step - loss: 1.0830 - val_loss: 0.5867
# Epoch 4/4
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8941 - val_loss: 0.5251
# Epoch 5/5
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7752 - val_loss: 0.4822
# Save Model:  select_k_best_brand_sample_NN_64_dr1e-01_16_dr1e-01_16_dr1e-01_lr1e-03_ep5.h5
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-75-b86bf8c12406> in <module>
#       1 model = neural_network(model_prefix="select_k_best_brand_sample", nodes=[64, 16, 16], dropouts = [0.1,0.1,0.1])
# ----> 2 model.fit(x_skb_select_train, y_train.values, x_skb_select_test, y_test.values,
#       3           n_epoch=20,epoch=1, bs=128)
#
# ~\OneDrive - The City College of New York\CCNY_Course\Applied_Machine_Learning_and_Data_Mining\codes\project-product-price-prediction\final\model_evaluation\keras_model.py in fit(self, trainData, trainLabel, testData, testLabel, n_epoch, epoch, bs)
#      49             loss.append([history.history['loss'],history.history['val_loss']])
#      50             if (i+1)%5 == 0:
# ---> 51                 save_model(dir=self.model_name, filename=self.model_name + "_ep%d.h5" % (i+1),
#      52                            model=self.model)
#      53
#
# ~\OneDrive - The City College of New York\CCNY_Course\Applied_Machine_Learning_and_Data_Mining\codes\project-product-price-prediction\final\helper\save_data.py in save_model(dir, filename, model)
#      29             os.makedirs(dir)
#      30     print("Save Model: ", filename)
# ---> 31     model.save('%s%s'%(dir,filename))
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options)
#    1976     ```
#    1977     """
# -> 1978     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
#    1979                     signatures, options)
#    1980
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\saving\save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options)
#     128           'to the Tensorflow SavedModel format (by setting save_format="tf") '
#     129           'or using `save_weights`.')
# --> 130     hdf5_format.save_model_to_hdf5(
#     131         model, filepath, overwrite, include_optimizer)
#     132   else:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     100         return
#     101
# --> 102     f = h5py.File(filepath, mode='w')
#     103     opened_new_file = True
#     104   else:
#
# ~\anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     404             with phil:
#     405                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
#     408                                swmr=swmr)
#
# ~\anaconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     177         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     178     elif mode == 'w':
# --> 179         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     180     elif mode == 'a':
#     181         # Open in append mode (read/write).
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = 'select_k_best_brand_sample_NN_64_dr1e-01_16_dr1e-01_16_dr1e-01_lr1e-03/select_k_best_brand_sample_NN_64_dr1e-01_16_dr1e-01_16_dr1e-01_lr1e-03_ep5.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 302)

# %%
model.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                32064
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                1040
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 33,393
# Trainable params: 33,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
skb_select_loss = np.load("%s/%s_loss.npy"%(model.model_name,model.model_name))[:,:,0]
plot_loss(skb_select_loss[:,0],skb_select_loss[:,1], title="select_k_best_brand_sample_loss")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-77-f709eb96ee40> in <module>
# ----> 1 skb_select_loss = np.load("%s/%s_loss.npy"%(model.model_name,model.model_name))[:,:,0]
#       2 plot_loss(skb_select_loss[:,0],skb_select_loss[:,1], title="select_k_best_brand_sample_loss")
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'select_k_best_brand_sample_NN_64_dr1e-01_16_dr1e-01_16_dr1e-01_lr1e-03/select_k_best_brand_sample_NN_64_dr1e-01_16_dr1e-01_16_dr1e-01_lr1e-03_loss.npy'

# %%
model.model_name

# %%
model = neural_network(model_name = "select_k_best_brand_sample_NN_64_dr1e-01_16_dr1e-01_16_dr1e-01_lr1e-03_ep20.h5")

# %%
model.model.summary()

# %%
skb_select_train_pred = model.predict(x_skb_select_train)
skb_select_test_pred = model.predict(x_skb_select_test)

# %%
result_df = model.evaluation(y_train, skb_select_train_pred, y_test, skb_select_test_pred, price_split=30,
                                                print_result = False)

# %%
result_df
