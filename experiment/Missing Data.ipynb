# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jinchen1036/Product-Price-Prediction/main/data/sample_data.csv")

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['train_id', 'name', 'item_condition_id', 'category_name', 'brand_name',
#        'price', 'shipping', 'item_description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   train_id           1000 non-null   int64
#  1   name               1000 non-null   object
#  2   item_condition_id  1000 non-null   int64
#  3   category_name      996 non-null    object
#  4   brand_name         561 non-null    object
#  5   price              1000 non-null   float64
#  6   shipping           1000 non-null   int64
#  7   item_description   1000 non-null   object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 62.6+ KB

# %%
df.head()
# Out:
#    train_id  ...                                   item_description
# 0    748447  ...                                  Film not included
# 1    674932  ...       Sip n Smoke ashtray. Would make a cute gift!
# 2    586672  ...  NWT. Matilda Jane Clothing weekender bag. Over...
# 3    846012  ...                                          12 inches
# 4   1026408  ...        13 patches left. Too strong for my husband.
#
# [5 rows x 8 columns]

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(df.sample(1000))

# %%
brand=df.iloc[:,4]
brand
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 995      Dansko
# 996         BKE
# 997         NaN
# 998    Rae Dunn
# 999    Champion
# Name: brand_name, Length: 1000, dtype: object

# %%
print( f"Determine how many unique brand_name are there?\n{len(brand.unique())}" )
# Out:
# Determine how many unique brand_name are there?
# 235

# %%
print( "Determine how many unique brand_name are there?\n%d" %len(brand.unique()) )
# Out:
# Determine how many unique brand_name are there?
# 235

# %%
print(f"How many rows have missing brand_name in this sample dataset?\n {brand.isnull().sum()}")
# Out:
# How many rows have missing brand_name in this sample dataset?
#  439

# %%
# for this type of missing data, it is good to use fillna method.
import numpy as np
brand.fillna(np.nan)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 995      Dansko
# 996         BKE
# 997         NaN
# 998    Rae Dunn
# 999    Champion
# Name: brand_name, Length: 1000, dtype: object

# %%
brand.sort_values()
# Out:
# 63            ALEX AND ANI
# 895    Abercrombie & Fitch
# 295    Abercrombie & Fitch
# 679                 Adidas
# 818                 Adidas
#               ...
# 983                    NaN
# 986                    NaN
# 990                    NaN
# 993                    NaN
# 997                    NaN
# Name: brand_name, Length: 1000, dtype: object

# %%
brand.value_counts()
# Out:
# PINK                 37
# Victoria's Secret    31
# Nike                 25
# LuLaRoe              19
# Rae Dunn             10
#                      ..
# Stussy                1
# GUESS                 1
# Belly Bandit®         1
# Lia Sophia            1
# Konami                1
# Name: brand_name, Length: 234, dtype: int64

# %%
df_brand=pd.DataFrame(brand)
df_brand.count()
# Out:
# brand_name    561
# dtype: int64
